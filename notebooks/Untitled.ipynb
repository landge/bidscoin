# %% [markdown]
# # Bærum to BIDS

# %%
from pathlib import Path
import os 
import pydicom
from collections import Counter

# %%
test_directory = Path("images")

# %%
glob_result = test_directory.glob('**/*')

# %%
possible_dicom_files_list = [x for x in glob_result if x.is_file()]

# %%
len(possible_dicom_files_list)
# Out:
# 269620

# %%
def make_series_description(tag_description):
    if tag_description == "CT":
        return "CT caput"
    elif tag_description == "CTA":
        return "CT angiography"
    elif tag_description == "MR":
        return "MR caput"

# %%
for path in possible_dicom_files_list:
    ds = pydicom.dcmread(path, stop_before_pixels=False)
    if isinstance(ds, pydicom.dicomdir.DicomDir):
        dicom_dirs.append('new dicomdir')
    elif isinstance(ds, pydicom.dataset.FileDataset):
        id_list = ds.PatientID.split('_')
        ds.PatientID = id_list[0]
        ds.SeriesDescription = make_series_description(id_list[1])
        ds.save_as('output' / path.parent)
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 for path in possible_dicom_files_list:
# ----> 2     ds = pydicom.dcmread(path, stop_before_pixels=False)
#       3     if isinstance(ds, pydicom.dicomdir.DicomDir):
#       4         dicom_dirs.append('new dicomdir')
#
# File ~/anaconda3/envs/bidscoin/lib/python3.10/site-packages/pydicom/filereader.py:993, in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#     991     caller_owns_file = False
#     992     logger.debug("Reading file '{0}'".format(fp))
# --> 993     fp = open(fp, 'rb')
#     994 elif fp is None or not hasattr(fp, "read") or not hasattr(fp, "seek"):
#     995     raise TypeError("dcmread: Expected a file path or a file-like, "
#     996                     "but got " + type(fp).__name__)
#
# ...

# %%
for path in possible_dicom_files_list:
    ds = pydicom.dcmread(path, stop_before_pixels= True)
    if isinstance(ds, pydicom.dicomdir.DicomDir):
        dicom_dirs.append('new dicomdir')
    elif isinstance(ds, pydicom.dataset.FileDataset):
        print(ds.PatientID)
    else:
        pass
# Out:
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# 221099
# ...

# %%
for dirpath, dirname, filename in os.walk(test_directory):
    print(dirpath, dirname, filename)
# Out:
# test_images ['sub-221099', 'sub-221098', 'sub-221095'] []
# test_images/sub-221099 ['CT'] []
# test_images/sub-221099/CT ['DICOM'] ['DICOMDIR']
# test_images/sub-221099/CT/DICOM ['22041910'] []
# test_images/sub-221099/CT/DICOM/22041910 ['36130000'] []
# ...
